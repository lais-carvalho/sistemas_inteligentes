# %% [markdown]
# ## Exercício 11.2
#
# Test the randomized_search_cv function using the following protocol:
#
# 1. Use the breast-bin.csv dataset
# 2. Create a LogisticRegression model
# 4. Perform a randomized search with the following hyperparameter distributions:
#
# • l2_penalty: distribution between 1 and 10 with 10 equal intervals (e.g., np.linspace(1, 10, 10))
#
# • alpha: distribution between 0.001 and 0.0001 with 100 equal intervals (e.g., np.linspace(0.001, 0.0001, 100))
#
# • max_iter: distribution between 1000 and 2000 with 200 equal intervals (e.g., np.linspace(1000, 2000, 200))
#
# 5. Use n_iter=10 and cv=3 folds for the cross validation.
# 6. Which scores do you obtain? What are the best score and best hyperparameters?

# %%
import sys
sys.path.append(r"C:\Users\Álvaro Magno\Desktop\sistemas_inteligentes\sistemas_inteligentes")

# %%
from src.si.io.csv_file import read_csv
dataset = r"C:\Users\Álvaro Magno\Desktop\sistemas_inteligentes\sistemas_inteligentes\datasets\breast_bin\breast-bin.csv"

data = read_csv(filename=dataset, features=True, label=True)

# %%
from src.si.models.logistic_regression import LogisticRegression
lg = LogisticRegression(l2_penalty=1, alpha=0.001, max_iter=1000)

# %%
import numpy as np
from src.si.model_selection.randomized_search import randomized_search_cv
from src.si.metrics.accuracy import accuracy

hyperparameter_grid = {
    "l2_penalty": np.linspace(1, 10, 10),
    "alpha": np.linspace(0.001, 0.0001, 100),
    "max_iter": np.linspace(1000, 2000, 200)
}

results = randomized_search_cv(lg,
                   dataset= data,
                   hyperparameter_grid = hyperparameter_grid,
                   scoring = accuracy,
                   cv= 3, n_iter = 10)

print("Todos os scores")
for hyperparams, score in zip(results['hyperparameters'], results['scores']):
    print(f"Score: {score}")
    
print("Melhores:")
print(f"Hiperparâmetros: {results['best_hyperparameters']}")
print(f"Melhor Score: {results['best_score']}")
# Out:
# Todos os scores
# Score: 0.9669540229885057
# Score: 0.9669540229885057
# Score: 0.9669540229885057
# Score: 0.9669540229885056
# Score: 0.9655172413793104
# Score: 0.9669540229885057
# Score: 0.9655172413793104
# Score: 0.9669540229885057
# Score: 0.9669540229885057
# Score: 0.9655172413793104
# Melhores:
# Hiperparâmetros: {'l2_penalty': np.float64(3.0), 'alpha': np.float64(0.00044545454545454543), 'max_iter': np.float64(1798.994974874372)}
# Melhor Score: 0.9669540229885057
