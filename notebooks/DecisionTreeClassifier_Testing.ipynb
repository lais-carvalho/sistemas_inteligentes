# %%
import sys
sys.path.append(r"C:\Users\Álvaro Magno\Desktop\sistemas_inteligentes\sistemas_inteligentes")

# %%
from src.si.io.csv_file import read_csv
from src.si.model_selection.split import train_test_split

from src.si.io.csv_file import read_csv
dataset = r"C:\Users\Álvaro Magno\Desktop\sistemas_inteligentes\sistemas_inteligentes\datasets\iris\iris.csv"

data = read_csv(filename=dataset, features=True, label=True)

# %%
from src.si.models.decision_tree_classifier import DecisionTreeClassifier
train, test = train_test_split(data, test_size=0.33, random_state=42)
model = DecisionTreeClassifier(min_sample_split=3, max_depth=3, mode='gini')
model.fit(train)
model.print_tree()
print(model.score(test))
# Out:
# petal_length <= 1.9
# 	left: Iris-setosa
# 	right: petal_width <= 1.7
# 	  left: petal_length <= 5.1
# 	    left: sepal_length <= 4.9
# 	      left: Iris-versicolor
# 	      right: Iris-versicolor
# 	    right: Iris-virginica
# 	  right: petal_length <= 4.8
# 	    left: sepal_length <= 5.9
# 	      left: Iris-versicolor
# 	      right: Iris-virginica
# 	    right: Iris-virginica
# 0.9795918367346939
