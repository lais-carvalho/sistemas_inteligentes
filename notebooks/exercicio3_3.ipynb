# %% [markdown]
# ## Exercício 3.3)
#
# Test the SelectPercentile class in a Jupyter notebook using the "iris.csv" dataset.

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/11.0 MB 13.4 MB/s eta 0:00:01
#    ------------------- -------------------- 5.2/11.0 MB 13.9 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 15.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 14.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
## Importando o iris
from sklearn.datasets import load_iris
iris = load_iris()
iris
print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
import sys
sys.path.append(r"C:\Users\Álvaro Magno\Desktop\sistemas_inteligentes\sistemas_inteligentes")

# %%
## Definindo o dataset com os dados do iris
from src.si.data.dataset import Dataset
dataset = Dataset(
    X=iris.data,
    y=iris.target,
    features=iris.feature_names,
    label="species"
)

# %%
## Testando a classe criada
from src.si.feature_selection.select_percentile import SelectPercentile
selector = SelectPercentile(percentile=50) 
selector = selector.fit(dataset)

transformed_dataset = selector.transform(dataset)

print("Features selecionadas:", transformed_dataset.features)
# Out:
# Features selecionadas: [np.str_('petal length (cm)'), np.str_('petal width (cm)')]
