# %%
import pandas as pd
## Exercício 1.1
df = pd.read_csv('iris.csv')

# %%
## Exercício 1.2
puv = df.iloc[:, -2]
puv.shape
# Out:
# (150,)

# %%
## Exercício 1.3
ultimas_10_amostras = df.iloc[-10:, :-1]
medias = ultimas_10_amostras.mean()
print(medias)
# Out:
# sepal length (cm)    6.45
# sepal width (cm)     3.03
# petal length (cm)    5.33
# petal width (cm)     2.17
# dtype: float64

# %%
## Exercício 1.4
menores_iguais_6 = df[(df.iloc[:, :-1] <= 6).all(axis=1)]
len(menores_iguais_6)
# Out:
# 89

# %%
## Exercício 1.5
diferente_i_setosa = df[(df.iloc[:, :] != 'Iris-setosa').all(axis=1)]
len(diferente_i_setosa)
# Out:
# 150

# %%
## Testes

# %%
import numpy as np
import pandas as pd

# Criando um DataFrame X com valores nulos
X = pd.DataFrame({
    'sepal_length': [5.1, 4.9, np.nan, 5.0, np.nan],
    'sepal_width': [3.5, np.nan, 3.1, 3.6, 3.0],
    'petal_length': [1.4, 1.4, 1.5, np.nan, 1.3],
    'petal_width': [0.2, 0.2, np.nan, 0.3, 0.2]
})

# Criando um vetor y para representar a classe
y = np.array(['Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor', 'Iris-setosa'])

print("X (com valores nulos):\n", X)
print("\ny (classe):\n", y)
# Out:
# X (com valores nulos):
#     sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          NaN           1.4          0.2
# 2           NaN          3.1           1.5          NaN
# 3           5.0          3.6           NaN          0.3
# 4           NaN          3.0           1.3          0.2
#
# y (classe):
#  ['Iris-setosa' 'Iris-setosa' 'Iris-virginica' 'Iris-versicolor'
#  'Iris-setosa']

# %%
## dropna()
has_any_na = X.iloc[:, :].isna().any(axis=1)
indx_na = np.argwhere(has_any_na)
X = np.delete(X, indx_na, axis=0)
y = np.delete(y, indx_na, axis=0)
print(X, y)
# Out:
# [[5.1 3.5 1.4 0.2]] ['Iris-setosa']

# %%
## fillna
has_any_na = X.iloc[:, :].isna()
indx_na = np.argwhere(has_any_na)
for i in indx_na:
    if value == "mean":
        mean_feature = X.iloc[:, i[1]].mean()
        X.iloc[i[0], i[1]] = mean_feature
    elif value == "median":
        median_feature = X.iloc[:, i[1]].median()
        X.liloc[i[0], i[1]] = median_feature
    else:
        X.iloc[i[0], i[1]] = value
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4        0.200
# 1           4.9          3.3           1.4        0.200
# 2           5.0          3.1           1.5        0.225
# 3           5.0          3.6           1.4        0.300
# 4           5.0          3.0           1.3        0.200

# %%
X = X.to_numpy()
tt = np.isnan(X)
tt[:, 1]
# Out:
# array([False,  True, False, False, False])

# %%
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, nan, 1.4, 0.2],
#        [nan, 3.1, 1.5, nan],
#        [5. , 3.6, nan, 0.3],
#        [nan, 3. , 1.3, 0.2]])

# %%
delete_X = X.copy()
delet_y = y.copy()

# %%
ind = [0,1]
np.delete(delete_X, ind, axis = 0)
# Out:
# array([[nan, 3.1, 1.5, nan],
#        [5. , 3.6, nan, 0.3],
#        [nan, 3. , 1.3, 0.2]])
